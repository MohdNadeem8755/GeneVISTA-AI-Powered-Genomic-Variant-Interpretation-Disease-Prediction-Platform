# %% [markdown]
# # 06 · Exploratory disease annotation ranking
# This experiment ranks future record-level MONDO disease annotation events when a VUS becomes pathogenic/likely pathogenic. It does not predict patient disease risk. Scores are uncalibrated. Vocabulary is selected using training labels only. The 2025–2026 interval has already been viewed in prior experiments; evaluation is exploratory, not a fresh external test.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd()
if ROOT.name == 'notebooks': ROOT = ROOT.parent
sys.path.insert(0,str(ROOT/'src'))
from disease_ranking import prepare, train
datasets,names=prepare()
# Out:
# Loading prepared historical cache

# %%
results=train(datasets,names)
display(results)
# Out:
# Feature matrix: train (1022507, 12365)
# Feature matrix: validation (1121932, 12365)
# Feature matrix: test (1456851, 12365)
# Trained: MONDO:0014038 Colorectal cancer, susceptibility to, 12 positive events 265
# D:\AncondaAPP\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:741: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# Trained: MONDO:0100062 genetic developmental and epileptic encephalopathy positive events 131
# D:\AncondaAPP\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:741: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# Trained: MONDO:0015356 Hereditary cancer-predisposing syndrome positive events 106
# ...

# %% [markdown]
# ## Interpretation
# Compare per-disease AP with event prevalence and inspect positive support. No positive events means AP is undefined. Do not interpret scores as calibrated disease probabilities. See the saved model_card.json for the target definition, cohort selection, and limitations.
